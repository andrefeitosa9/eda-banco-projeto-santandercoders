# %% [markdown]
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:center; border-radius:10px 10px; margin-bottom: -15px;"><strong>ANÁLISE EXPLORATÓRIA DE CHURN DO BLUE BANK</strong></p>

# %% [markdown]
# <p align="center">
#   <img src="../03-Recursos/churn.jpg" alt="Churn Analysis" width="600"/>
# </p>

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:center; border-radius:10px 10px; margin-bottom: -15px;"><strong>SUMÁRIO</strong></p>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">1. INTRODUÇÃO 🚀</span></strong></p>](#1) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">2. OBJETIVO 🎯</span></strong></p>](#2) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">3. IMPORTAÇÃO DE BIBLIOTECAS 📚</span></strong></p>](#3) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">4. CARREGAMENTO DOS DADOS 🔄</span></strong></p>](#4) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">5. LIMPEZA E PRÉ-PROCESSAMENTO DOS DADOS 🔍</span></strong></p>](#5) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">6. ANÁLISE EXPLORATÓRIA DE DADOS (AED/EDA) 💡</span></strong></p>](#6) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">7. INSIGHTS E CONCLUSÕES 📊</span></strong></p>](#7) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">8. RECOMENDAÇÕES 📝</span></strong></p>](#8) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">9. CONCLUSÃO 🏁</span></strong></p>](#9) <br>

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="1"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>1. INTRODUÇÃO 🚀</strong></p>
#
# - **Este projeto de Análise de Churn do Blue Bank tem como objetivo explorar e analisar o comportamento dos clientes do banco para identificar os principais fatores que influenciam suas decisões de permanecer ou deixar o banco. O conjunto de dados utilizado contém informações diversas sobre os clientes, como idade, saldo bancário, status de membro ativo, número de produtos, e possibilidade de churn, entre outros. A descrição detalhada de cada uma das colunas será abordada na seção de Limpeza e Pré-processamento dos Dados.**

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="2"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>2. OBJETIVO  🎯</strong></p>
#
# - **O objetivo principal deste projeto é conduzir uma Análise Exploratória de Dados (EDA) sobre o conjunto de dados de churn dos clientes do Blue Bank. A análise busca identificar padrões e insights que possam explicar os fatores que influenciam os clientes a deixarem o banco. Especificamente, a análise se concentrará em responder as seguintes perguntas de negócio:**
#
#     - **Como características como idade, saldo bancário, número de produtos e atividade do membro impactam a probabilidade de churn dos clientes?**
#     - **Existe uma correlação entre a geografia dos clientes e suas taxas de churn?**
#     - **Os clientes com cartão de crédito são mais propensos a permanecer no banco comparado aos que não possuem?**
#     - **Qual o impacto do salário estimado na decisão do cliente de permanecer ou deixar o banco?**
#     - **O tempo de relacionamento com o banco (tenure) impacta a lealdade dos clientes?**
#     - **Como a idade dos clientes afeta a probabilidade de sair do banco?**
#     - **Comparar a taxa de churn entre clientes ativos e inativos.**
#     - **O país de origem dos clientes influencia na decisão de sair?**
#     - **Analisar se clientes com mais produtos tendem a ser mais leais ao banco.**
#     - **Existe uma relação entre a pontuação de crédito e a taxa de churn?**
#     - **Avaliar se clientes com maior pontuação de crédito são mais propensos a permanecer no banco.**
#     - **Investigar a correlação entre o salário estimado e a retenção.**
#     - **O banco está perdendo mais clientes em algum grupo específico (idade, país, gênero)?**
#     - **Traçar o perfil dos clientes do banco no geral.**
#
# - **Essas perguntas visam descobrir oportunidades para o Blue Bank aprimorar suas estratégias de retenção de clientes, oferecendo insights valiosos que podem ser utilizados para reduzir a taxa de churn e melhorar a satisfação geral do cliente.**

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="3"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>3. IMPORTAÇÃO DE BIBLIOTECAS E CONFIGURAÇÃO DE ESTILO 📚</strong></p>
#
# - **Nesta seção, importamos todas as bibliotecas essenciais para a execução da análise de dados, como Pandas, Matplotlib, Seaborn e NumPy, que são fundamentais para a manipulação de dados, visualização e análise estatística. Adicionalmente, configuramos estilos visuais para assegurar que todas as visualizações sejam consistentes e reflitam a identidade visual do Blue Bank, utilizando uma paleta de cores em tons de azul. Além disso, exibimos as versões de cada biblioteca utilizada para garantir a reprodutibilidade e documentação do ambiente de desenvolvimento.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np
from platform import python_version

# Configuração de estilos visuais para os gráficos
sns.set(style="whitegrid")  # Define o estilo do Seaborn para melhor visualização
blue_palette = sns.color_palette("Blues")  # Cria uma paleta de cores em tons de azul
sns.set_palette(blue_palette)  # Aplica a paleta de cores aos gráficos

# Tabela de versões das bibliotecas e do Python
library_versions = {
    "Pandas": pd.__version__,
    "Matplotlib": matplotlib.__version__,
    "Seaborn": sns.__version__,
    "NumPy": np.__version__
}

# Exibindo as versões das bibliotecas
print("Versões das Bibliotecas:\n")
print(f"{'Biblioteca':<20} | {'Versão':>10}")
for nome, versao in library_versions.items():
    print(f"{nome:<20} | {versao:>10}")

# Versão do Python
print("\nVersão do Python:")
print(python_version())
# Out:
# Versões das Bibliotecas:
#
# Biblioteca           |     Versão
# Pandas               |      2.2.2
# Matplotlib           |      3.8.1
# Seaborn              |     0.13.0
# NumPy                |     1.26.1
#
# Versão do Python:
# 3.11.9

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="4"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>4. CARREGAMENTO DOS DADOS 🔄</strong></p>
#
# - **Nesta seção, carregamos o conjunto de dados do Blue Bank, que contém informações detalhadas sobre os clientes e seus status de churn. Este passo é crucial para começar a nossa análise exploratória.**

# %%
# Carregando os dados do arquivo CSV
data_path = "../01-Base-de-Dados/blue-bank-churn.csv"  # Caminho da pasta com arquivo de análise
df = pd.read_csv(data_path)

# Exibindo as primeiras linhas do DataFrame para verificar a importação
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
# 6       7       0.00              2          1               1
# 7       4  115046.74              4          1               0
# 8       4  142051.07              2          0               1
# 9       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# 5        149756.71       1
# 6         10062.80       0
# 7        119346.88       1
# 8         74940.50       0
# 9         71725.73       0

# %%
# Exibindo informações básicas sobre o DataFrame para entender a estrutura dos dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="5"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>5. LIMPEZA E PRÉ-PROCESSAMENTO DOS DADOS 🔍</strong></p>
#
# - **Antes de iniciar a análise exploratória, é essencial garantir que os dados estejam limpos e bem formatados. Esta seção aborda a limpeza de dados, tratamento de valores nulos, correção de tipos de dados e qualquer outra transformação necessária para preparar o dataset. Estas etapas são cruciais para garantir a qualidade e precisão das análises subsequentes.**

# %%
#Exibição do Dataframe atual para avaliarmos possíveis mudanças:
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# Dicionário com as descrições detalhadas das colunas do DataFrame. Esta informação é crucial para entender o significado de cada campo e sua importância para a análise de churn.
descricao_colunas = {
    "RowNumber": "Número do registro (linha) no dataset, usado apenas como índice.",
    "CustomerId": "Identificador único do cliente no banco, crucial para identificação individual.",
    "Surname": "Sobrenome do cliente, não tem impacto direto na análise.",
    "CreditScore": "Pontuação de crédito do cliente, indicando sua solvência e potencial risco financeiro.",
    "Geography": "País de residência do cliente, importante para análise regional de churn.",
    "Gender": "Gênero do cliente, útil para análise demográfica.",
    "Age": "Idade do cliente, um fator significativo na decisão de produtos bancários.",
    "Tenure": "Número de anos que o cliente está com o banco, indicativo de lealdade e satisfação.",
    "Balance": "Saldo atual na conta bancária do cliente, pode indicar satisfação com o banco.",
    "NumOfProducts": "Número de produtos bancários que o cliente utiliza, reflete a profundidade do relacionamento.",
    "HasCrCard": "Indica se o cliente possui um cartão de crédito (1 = Sim, 0 = Não), relevante para serviços cruzados.",
    "IsActiveMember": "Indica se o cliente é um membro ativo (1 = Sim, 0 = Não), importante para engajamento.",
    "EstimatedSalary": "Salário estimado anual do cliente, correlaciona com potencial de investimento.",
    "Exited": "Indica se o cliente deixou o banco (1 = Sim, 0 = Não), variável-alvo para análise de churn."
}

# Convertendo o dicionário em um DataFrame para facilitar a visualização e entendimento das colunas
df_descricao_colunas = pd.DataFrame(list(descricao_colunas.items()), columns=['Coluna', 'Descrição'])

# Exibindo o DataFrame para visualização das descrições das colunas
df_descricao_colunas
# Out:
#              Coluna                                          Descrição
# 0         RowNumber  Número do registro (linha) no dataset, usado a...
# 1        CustomerId  Identificador único do cliente no banco, cruci...
# 2           Surname  Sobrenome do cliente, não tem impacto direto n...
# 3       CreditScore  Pontuação de crédito do cliente, indicando sua...
# 4         Geography  País de residência do cliente, importante para...
# 5            Gender  Gênero do cliente, útil para análise demográfica.
# 6               Age  Idade do cliente, um fator significativo na de...
# 7            Tenure  Número de anos que o cliente está com o banco,...
# 8           Balance  Saldo atual na conta bancária do cliente, pode...
# 9     NumOfProducts  Número de produtos bancários que o cliente uti...
# 10        HasCrCard  Indica se o cliente possui um cartão de crédit...
# 11   IsActiveMember  Indica se o cliente é um membro ativo (1 = Sim...
# 12  EstimatedSalary  Salário estimado anual do cliente, correlacion...
# 13           Exited  Indica se o cliente deixou o banco (1 = Sim, 0...

# %%
# Exibindo a soma de valores nulos para cada coluna no DataFrame
null_values = df.isnull().sum()

# Verificando se há valores nulos e exibindo os resultados
print("Quantidade de valores nulos por coluna no dataset:")
print(null_values)
# Out:
# Quantidade de valores nulos por coluna no dataset:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Renomeando as colunas do DataFrame para nomes em português com estilo snake_case
colunas_traduzidas = {
    'RowNumber': 'numero_linha',
    'CustomerId': 'id_cliente',
    'Surname': 'sobrenome',
    'CreditScore': 'pontuacao_credito',
    'Geography': 'pais',
    'Gender': 'genero',
    'Age': 'idade',
    'Tenure': 'tempo_relacionamento',
    'Balance': 'saldo',
    'NumOfProducts': 'numero_produtos',
    'HasCrCard': 'possui_cartao_credito',
    'IsActiveMember': 'membro_ativo',
    'EstimatedSalary': 'salario_estimado',
    'Exited': 'saiu_banco'
}

# Aplicando as novas nomenclaturas das colunas ao DataFrame
df.rename(columns=colunas_traduzidas, inplace=True)

# Exibindo as primeiras linhas do DataFrame para verificar as novas nomenclaturas de colunas
df.head()
# Out:
#    numero_linha  id_cliente sobrenome  pontuacao_credito    pais  genero  \
# 0             1    15634602  Hargrave                619  France  Female
# 1             2    15647311      Hill                608   Spain  Female
# 2             3    15619304      Onio                502  France  Female
# 3             4    15701354      Boni                699  France  Female
# 4             5    15737888  Mitchell                850   Spain  Female
#
#    idade  tempo_relacionamento      saldo  numero_produtos  \
# 0     42                     2       0.00                1
# 1     41                     1   83807.86                1
# 2     42                     8  159660.80                3
# 3     39                     1       0.00                2
# 4     43                     2  125510.82                1
#
#    possui_cartao_credito  membro_ativo  salario_estimado  saiu_banco
# 0                      1             1         101348.88           1
# 1                      0             1         112542.58           0
# 2                      1             0         113931.57           1
# 3                      0             0          93826.63           0
# 4                      1             1          79084.10           0

# %%
# Mostrando os valores únicos presentes nas colunas 'pais' e 'genero'
print("Valores únicos na coluna 'pais':", df['pais'].unique())
print("Valores únicos na coluna 'genero':", df['genero'].unique())

# Dicionários de tradução para as colunas 'pais' e 'genero'
traducao_paises = {
    'France': 'França',
    'Spain': 'Espanha',
    'Germany': 'Alemanha'
}

traducao_genero = {
    'Female': 'Feminino',
    'Male': 'Masculino'
}

# Aplicando as traduções
df['pais'] = df['pais'].map(traducao_paises)
df['genero'] = df['genero'].map(traducao_genero)

# Exibindo as primeiras linhas do DataFrame para verificar as traduções
print("\nApós a tradução:")
df[['pais', 'genero']].head()
# Out:
# Valores únicos na coluna 'pais': ['France' 'Spain' 'Germany']
# Valores únicos na coluna 'genero': ['Female' 'Male']
#
# Após a tradução:
#       pais    genero
# 0   França  Feminino
# 1  Espanha  Feminino
# 2   França  Feminino
# 3   França  Feminino
# 4  Espanha  Feminino

# %%
# Removendo colunas desnecessárias para a análise de churn
# As colunas 'numero_linha' e 'sobrenome' são removidas porque não contribuem para a análise ou insights sobre o churn dos clientes.

# Removendo as colunas do DataFrame
df.drop(['numero_linha', 'sobrenome'], axis=1, inplace=True)

# Exibindo as primeiras linhas do DataFrame após a remoção das colunas para confirmar a alteração
print("DataFrame após a remoção das colunas 'numero_linha' e 'sobrenome':")
df.head()
# Out:
# DataFrame após a remoção das colunas 'numero_linha' e 'sobrenome':
#    id_cliente  pontuacao_credito     pais    genero  idade  \
# 0    15634602                619   França  Feminino     42
# 1    15647311                608  Espanha  Feminino     41
# 2    15619304                502   França  Feminino     42
# 3    15701354                699   França  Feminino     39
# 4    15737888                850  Espanha  Feminino     43
#
#    tempo_relacionamento      saldo  numero_produtos  possui_cartao_credito  \
# 0                     2       0.00                1                      1
# 1                     1   83807.86                1                      0
# 2                     8  159660.80                3                      1
# 3                     1       0.00                2                      0
# 4                     2  125510.82                1                      1
#
#    membro_ativo  salario_estimado  saiu_banco
# 0             1         101348.88           1
# 1             1         112542.58           0
# 2             0         113931.57           1
# 3             0          93826.63           0
# 4             1          79084.10           0

# %%
# Atualização do dicionário com as descrições das colunas do DataFrame após as modificações
descricao_colunas_atualizada = {
    'id_cliente': 'Identificador único do cliente no banco, crucial para identificação individual.',
    'pontuacao_credito': 'Pontuação de crédito do cliente, indicando sua solvência e potencial risco financeiro.',
    'pais': 'País de residência do cliente, importante para análise regional de churn.',
    'genero': 'Gênero do cliente, útil para análise demográfica.',
    'idade': 'Idade do cliente, um fator significativo na decisão de produtos bancários.',
    'tempo_relacionamento': 'Número de anos que o cliente está com o banco, indicativo de lealdade e satisfação.',
    'saldo': 'Saldo atual na conta bancária do cliente, pode indicar satisfação com o banco.',
    'numero_produtos': 'Número de produtos bancários que o cliente utiliza, reflete a profundidade do relacionamento.',
    'possui_cartao_credito': 'Indica se o cliente possui um cartão de crédito (1 = Sim, 0 = Não), relevante para serviços cruzados.',
    'membro_ativo': 'Indica se o cliente é um membro ativo (1 = Sim, 0 = Não), importante para engajamento.',
    'salario_estimado': 'Salário estimado anual do cliente, correlaciona com potencial de investimento.',
    'saiu_banco': 'Indica se o cliente deixou o banco (1 = Sim, 0 = Não), variável-alvo para análise de churn.'
}

# Convertendo o dicionário atualizado em um DataFrame para facilitar a visualização e entendimento das colunas
df_descricao_colunas_atualizada = pd.DataFrame(list(descricao_colunas_atualizada.items()), columns=['Coluna', 'Descrição'])

# Exibindo o DataFrame atualizado para visualização das descrições das colunas
print("Descrição atualizada das colunas do DataFrame:")
df_descricao_colunas_atualizada
# Out:
# Descrição atualizada das colunas do DataFrame:
#                    Coluna                                          Descrição
# 0              id_cliente  Identificador único do cliente no banco, cruci...
# 1       pontuacao_credito  Pontuação de crédito do cliente, indicando sua...
# 2                    pais  País de residência do cliente, importante para...
# 3                  genero  Gênero do cliente, útil para análise demográfica.
# 4                   idade  Idade do cliente, um fator significativo na de...
# 5    tempo_relacionamento  Número de anos que o cliente está com o banco,...
# 6                   saldo  Saldo atual na conta bancária do cliente, pode...
# 7         numero_produtos  Número de produtos bancários que o cliente uti...
# 8   possui_cartao_credito  Indica se o cliente possui um cartão de crédit...
# 9            membro_ativo  Indica se o cliente é um membro ativo (1 = Sim...
# 10       salario_estimado  Salário estimado anual do cliente, correlacion...
# 11             saiu_banco  Indica se o cliente deixou o banco (1 = Sim, 0...

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="6"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>6. ANÁLISE EXPLORATÓRIA DE DADOS (AED/EDA) 💡</strong></p>
#
# - **Nesta seção, conduziremos uma análise exploratória detalhada dos dados do Blue Bank, utilizando visualizações gráficas e estatísticas descritivas para identificar padrões e correlações que possam influenciar a decisão de um cliente em permanecer ou deixar o banco. Analisaremos variáveis como idade, saldo, número de produtos, entre outros, para compreender melhor os fatores que contribuem para o churn dos clientes. Esta etapa é fundamental para desdobrar insights que ajudarão na formulação de estratégias eficazes de retenção de clientes.**
#     - **Focaremos em responder às seguintes perguntas de negócio, que foram identificadas como cruciais para entender o churn dos clientes do Blue Bank:**
#         - **Como características como idade, saldo bancário, número de produtos e atividade do membro impactam a probabilidade de churn dos clientes?**
#         - **Existe uma correlação entre a geografia dos clientes e suas taxas de churn?**
#         - **Os clientes com cartão de crédito são mais propensos a permanecer no banco comparado aos que não possuem?**
#         - **Qual o impacto do salário estimado na decisão do cliente de permanecer ou deixar o banco?**
#         - **O tempo de relacionamento com o banco (tenure) impacta a lealdade dos clientes?**
#         - **Como a idade dos clientes afeta a probabilidade de sair do banco?**
#         - **Comparar a taxa de churn entre clientes ativos e inativos.**
#         - **O país de origem dos clientes influencia na decisão de sair?**
#         - **Analisar se clientes com mais produtos tendem a ser mais leais ao banco.**
#         - **Existe uma relação entre a pontuação de crédito e a taxa de churn?**
#         - **Avaliar se clientes com maior pontuação de crédito são mais propensos a permanecer no banco.**
#         - **Investigar a correlação entre o salário estimado e a retenção.**
#         - **O banco está perdendo mais clientes em algum grupo específico (idade, país, gênero)?**
#         - **Traçar o perfil dos clientes do banco no geral.**
#
# - **Cada uma dessas perguntas será explorada individualmente, utilizando técnicas de análise de dados e visualização para extrair insights relevantes e acionáveis.**

# %%
df.head()
# Out:
#    id_cliente  pontuacao_credito     pais    genero  idade  \
# 0    15634602                619   França  Feminino     42
# 1    15647311                608  Espanha  Feminino     41
# 2    15619304                502   França  Feminino     42
# 3    15701354                699   França  Feminino     39
# 4    15737888                850  Espanha  Feminino     43
#
#    tempo_relacionamento      saldo  numero_produtos  possui_cartao_credito  \
# 0                     2       0.00                1                      1
# 1                     1   83807.86                1                      0
# 2                     8  159660.80                3                      1
# 3                     1       0.00                2                      0
# 4                     2  125510.82                1                      1
#
#    membro_ativo  salario_estimado  saiu_banco
# 0             1         101348.88           1
# 1             1         112542.58           0
# 2             0         113931.57           1
# 3             0          93826.63           0
# 4             1          79084.10           0

# %%
df_espanha = df[df['pais'] == "Espanha"].copy()
df_alemanha = df[df['pais'] == "Alemanha"].copy()
df_franca = df[df['pais'] == "França"].copy()

# %%
# Isso é melhor para quando for começar a comparar churns. Trazer novas features para a análise
# Criei uma lista faixa de idades para facilitar a divisão de qual faixa de idade o usuário
# está e assim analisar se é outlier ou não dentro daquela faixa

faixas_idade = list(range(18, 94, 5))
faixas_idade
# Out:
# [18, 23, 28, 33, 38, 43, 48, 53, 58, 63, 68, 73, 78, 83, 88, 93]

# %%
df['faixa_etaria'] = pd.cut(df['idade'], bins=faixas_idade, right=False)

df_espanha['faixa_etaria'] = pd.cut(df_espanha['idade'], bins=faixas_idade, right=False)

df_alemanha['faixa_etaria'] = pd.cut(df_alemanha['idade'], bins=faixas_idade, right=False)

df_franca['faixa_etaria'] = pd.cut(df_franca['idade'], bins=faixas_idade, right=False)

# %%
# Função antiga

# def fazer_graficos_histogramas(coluna):

#     print(f'\nPara a coluna {coluna}: \n')
    
#     if coluna == 'faixa_etaria':
#         plt.figure(figsize=(12,8))
#         df[coluna] = df[coluna].astype(str)
    
#     if len(df[coluna].unique().tolist()) > 5:
#         print(df[coluna].describe())
#     if len(df[coluna].unique().tolist()) < 10:
#         print(df[coluna].value_counts(1))
#     print()

#     sns.histplot(data = df,
#             x = coluna,
#             color=sns.color_palette("Blues", 10)[-3],
#             hue=df['saiu_banco'],
#             multiple='stack',
#             palette={0: "blue", 1: "red"})  # Azul para quem ficou, vermelho para quem saiu
    
#     plt.show()

#     # Proporções e cálculos de impacto em saída ou não
#     nome_coluna = coluna + "_intervalada"

#     df_proporcoes_corrigido = df.copy()
    


#     if len(df[coluna].unique().tolist()) > 20:
#         df_proporcoes_corrigido[nome_coluna] = pd.cut(df[coluna], bins=20, right=True)
#         df_proporcoes_corrigido[nome_coluna] = df_proporcoes_corrigido[nome_coluna].astype(str)

#         df_proporcoes_agrupado = df_proporcoes_corrigido.groupby(nome_coluna)['saiu_banco'].value_counts(normalize=True).unstack()
#         df_proporcoes_agrupado = df_proporcoes_agrupado.fillna(0)

#         df_proporcoes_agrupado = df_proporcoes_agrupado * 100

#         # Formata os valores como porcentagem com 2 casas decimais
#         df_proporcoes_agrupado = df_proporcoes_agrupado.map(lambda x: f'{x:.2f}%')

#         df_proporcoes_agrupado.style.background_gradient(cmap="Blues")

#         print(df_proporcoes_agrupado)

#     else:
#         df_proporcoes_agrupado = df.groupby(coluna)['saiu_banco'].value_counts(normalize=True).unstack()
        
#         df_proporcoes_agrupado = df_proporcoes_agrupado * 100

#         # Formata os valores como porcentagem com 2 casas decimais
#         df_proporcoes_agrupado = df_proporcoes_agrupado.map(lambda x: f'{x:.2f}%')

#         df_proporcoes_agrupado.style.background_gradient(cmap="Blues")

#         print(df_proporcoes_agrupado)


#     print("*-"*50)
#     print()

# %%
def calcular_limites_outlier(dataframe, coluna):
    dados = dataframe[coluna]
    
    q1 = np.quantile(dados, 0.25)
    q3 = np.quantile(dados, 0.75)
    
    iqr = q3 - q1
    
    limite_inferior = q1 - 1.5*iqr
    limite_superior =  q3 + 1.5*iqr
    
    return limite_inferior, limite_superior

def eh_outlier(dado, dataframe, coluna):

    limite_inferior, limite_superior = calcular_limites_outlier(dataframe, coluna)
    if dado < limite_inferior or dado > limite_superior:
        return 1
    else: 
        return 0

# %%
def calcular_limites_outlier_faixa_etaria(dataframe, coluna, faixa_etaria):

    dados_faixa_etaria = dataframe[dataframe['faixa_etaria'] == faixa_etaria]
    dados = dados_faixa_etaria[coluna]
    
    q1 = np.quantile(dados, 0.25)
    q3 = np.quantile(dados, 0.75)
    
    iqr = q3 - q1
    
    limite_inferior = q1 - 1.5*iqr
    limite_superior =  q3 + 1.5*iqr
    
    return limite_inferior, limite_superior


def eh_outlier_na_faixa_etaria(dado, dataframe, coluna, faixa_etaria):

    limite_inferior, limite_superior = calcular_limites_outlier_faixa_etaria(dataframe, coluna, faixa_etaria)
    if dado < limite_inferior or dado > limite_superior:
        return 1
    else: 
        return 0

# %%
def calcular_limites_outlier_pais(dataframe, coluna, pais):

    dados_faixa_etaria = dataframe[dataframe['pais'] == pais]
    dados = dados_faixa_etaria[coluna]
    
    q1 = np.quantile(dados, 0.25)
    q3 = np.quantile(dados, 0.75)
    
    iqr = q3 - q1
    
    limite_inferior = q1 - 1.5*iqr
    limite_superior =  q3 + 1.5*iqr
    
    return limite_inferior, limite_superior


def eh_outlier_pais(dado, dataframe, coluna, pais):

    limite_inferior, limite_superior = calcular_limites_outlier_pais(dataframe, coluna, pais)
    if dado < limite_inferior or dado > limite_superior:
        return 1
    else: 
        return 0

# %%
colunas_para_calcular_outliers = [
 'pontuacao_credito',
 'idade',
 'tempo_relacionamento',
 'saldo',
 'numero_produtos',
 'salario_estimado']

colunas_para_calcular_outliers_com_faixa_etaria = [
    'pontuacao_credito',
    'tempo_relacionamento',
    'saldo',
    'numero_produtos',
    'salario_estimado'
]

colunas_para_calcular_outliers_com_pais = [
    'pontuacao_credito',
    'tempo_relacionamento',
    'saldo',
    'numero_produtos',
    'salario_estimado'
]

# %%
for coluna in colunas_para_calcular_outliers:
    nome_nova_coluna = "outlier_" + coluna
    df[nome_nova_coluna] = df[coluna].apply(lambda x: eh_outlier(x, dataframe=df, coluna=coluna))
    print(f'Número de outliers na {nome_nova_coluna}: {df[nome_nova_coluna].sum()}')

print()

for coluna in colunas_para_calcular_outliers_com_faixa_etaria:
    nome_nova_coluna = "outlier_faixa_etaria_" + coluna
    df[nome_nova_coluna] = df.apply(
        lambda row: eh_outlier_na_faixa_etaria(row[coluna], dataframe=df, coluna=coluna, faixa_etaria=row['faixa_etaria']),
        axis=1
    )    
    
    print(f'Número de outliers na {nome_nova_coluna}: {df[nome_nova_coluna].sum()}')

print()

for coluna in colunas_para_calcular_outliers_com_pais:
    nome_nova_coluna = "outlier_pais_" + coluna
    df[nome_nova_coluna] = df.apply(
        lambda row: eh_outlier_pais(row[coluna], dataframe=df, coluna=coluna, pais=row['pais']),
        axis=1
    )    
    
    print(f'Número de outliers na {nome_nova_coluna}: {df[nome_nova_coluna].sum()}')
# Out:
# Número de outliers na outlier_pontuacao_credito: 15
# Número de outliers na outlier_idade: 359
# Número de outliers na outlier_tempo_relacionamento: 0
# Número de outliers na outlier_saldo: 0
# Número de outliers na outlier_numero_produtos: 60
# Número de outliers na outlier_salario_estimado: 0
#
# Número de outliers na outlier_faixa_etaria_pontuacao_credito: 13
# Número de outliers na outlier_faixa_etaria_tempo_relacionamento: 0
# Número de outliers na outlier_faixa_etaria_saldo: 1
# Número de outliers na outlier_faixa_etaria_numero_produtos: 61
# Número de outliers na outlier_faixa_etaria_salario_estimado: 0
#
# Número de outliers na outlier_pais_pontuacao_credito: 17
# Número de outliers na outlier_pais_tempo_relacionamento: 0
# Número de outliers na outlier_pais_saldo: 33
# Número de outliers na outlier_pais_numero_produtos: 60
# Número de outliers na outlier_pais_salario_estimado: 0

# %%
# calculando outliers nos df de países separados


for coluna in colunas_para_calcular_outliers:
    nome_nova_coluna = "outlier_" + coluna
    df[nome_nova_coluna] = df[coluna].apply(lambda x: eh_outlier(x, dataframe=df_espanha, coluna=coluna))
    print(f'Número de outliers na Espanha {nome_nova_coluna}: {df[nome_nova_coluna].sum()}')

print()


for coluna in colunas_para_calcular_outliers:
    nome_nova_coluna = "outlier_" + coluna
    df[nome_nova_coluna] = df[coluna].apply(lambda x: eh_outlier(x, dataframe=df_alemanha, coluna=coluna))
    print(f'Número de outliers na Alemanha {nome_nova_coluna}: {df[nome_nova_coluna].sum()}')

print()



for coluna in colunas_para_calcular_outliers:
    nome_nova_coluna = "outlier_" + coluna
    df[nome_nova_coluna] = df[coluna].apply(lambda x: eh_outlier(x, dataframe=df_franca, coluna=coluna))
    print(f'Número de outliers na França {nome_nova_coluna}: {df[nome_nova_coluna].sum()}')

print()
# Out:
# Número de outliers na Espanha outlier_pontuacao_credito: 17
# Número de outliers na Espanha outlier_idade: 359
# Número de outliers na Espanha outlier_tempo_relacionamento: 0
# Número de outliers na Espanha outlier_saldo: 0
# Número de outliers na Espanha outlier_numero_produtos: 60
# Número de outliers na Espanha outlier_salario_estimado: 0
#
# Número de outliers na Alemanha outlier_pontuacao_credito: 14
# Número de outliers na Alemanha outlier_idade: 282
# Número de outliers na Alemanha outlier_tempo_relacionamento: 0
# Número de outliers na Alemanha outlier_saldo: 3767
# Número de outliers na Alemanha outlier_numero_produtos: 60
# Número de outliers na Alemanha outlier_salario_estimado: 0
#
# Número de outliers na França outlier_pontuacao_credito: 14
# Número de outliers na França outlier_idade: 411
# Número de outliers na França outlier_tempo_relacionamento: 0
# Número de outliers na França outlier_saldo: 0
# Número de outliers na França outlier_numero_produtos: 60
# Número de outliers na França outlier_salario_estimado: 0

# %%
colunas_com_boxplot = ['pontuacao_credito', 'idade', 'tempo_relacionamento', 'saldo', 'salario_estimado']

# %%
def fazer_graficos_histogramas(coluna, dataframe):
    print(f'\nPara a coluna {coluna}: \n')
    
    if coluna == 'faixa_etaria':
        plt.figure(figsize=(12, 8))
        dataframe[coluna] = dataframe[coluna].astype(str)
    
    # Se houver mais de 5 valores únicos, exibe o describe
    if len(dataframe[coluna].unique().tolist()) > 5:
        print(dataframe[coluna].describe())
    
    # Se houver menos de 10 valores únicos, exibe as contagens relativas
    if len(dataframe[coluna].unique().tolist()) < 10:
        print(dataframe[coluna].value_counts(1))
    print()

    # Boxplot e histograma combinados para colunas numéricas
    if coluna in colunas_com_boxplot:

        # Gráfico combinado de histograma e boxplot
        fig, (ax_box, ax_hist) = plt.subplots(
            nrows=2, 
            sharex=True, 
            gridspec_kw={"height_ratios": (0.25, 0.75)},
            figsize=(12, 8)
        )
        
        sns.boxplot(
            data=dataframe, x=coluna, ax=ax_box, showmeans=True, color="lightblue"
        )
        ax_box.set_title(f"Boxplot de {coluna}")

        # Histograma com barras empilhadas para 'saiu_banco'
        sns.histplot(
            data=dataframe,
            x=coluna,
            hue='saiu_banco',
            multiple='stack',
            palette={0: "blue", 1: "red"},
            ax=ax_hist
        )
        ax_hist.set_title(f"Histograma de {coluna}")
        ax_hist.set_xlabel(f"{coluna}")
        
        # Adiciona linhas de média e mediana no histograma
        media = dataframe[coluna].mean()
        mediana = dataframe[coluna].median()
        
        ax_hist.axvline(media, color="green", linestyle="--", linewidth=2)
        ax_hist.axvline(mediana, color="black", linestyle="-", linewidth=2)

        # Anotações para média e mediana
        ax_hist.annotate(f'Média: {media:.2f}', 
                         xy=(media, ax_hist.get_ylim()[1] * 0.85), 
                         xytext=(media + 1, ax_hist.get_ylim()[1] * 0.9),
                         textcoords='data',
                         color='green', fontsize=12,
                         bbox=dict(facecolor='white', alpha=0.6),
                         arrowprops=dict(facecolor='green', arrowstyle='->'))

        ax_hist.annotate(f'Mediana: {mediana:.2f}', 
                         xy=(mediana, ax_hist.get_ylim()[1] * 0.6), 
                         xytext=(mediana - 2, ax_hist.get_ylim()[1] * 0.65),
                         textcoords='data',
                         color='black', fontsize=12,
                         bbox=dict(facecolor='white', alpha=0.6),
                         arrowprops=dict(facecolor='black', arrowstyle='->'))

        plt.tight_layout()
        plt.show()

    # Apenas histograma para colunas categóricas
    else:
        plt.figure(figsize=(12, 8))
        sns.histplot(
            data=dataframe,
            x=coluna,
            hue='saiu_banco',
            multiple='stack',
            palette={0: "blue", 1: "red"}
        )
        
        plt.title(f"Histograma de {coluna}")
        plt.xlabel(f"{coluna}")
        plt.tight_layout()
        plt.show()

    # Proporções e cálculos de impacto em saída ou não
    nome_coluna = coluna + "_intervalada"
    df_proporcoes_corrigido = dataframe.copy()

    if len(dataframe[coluna].unique().tolist()) > 20:
        df_proporcoes_corrigido[nome_coluna] = pd.cut(dataframe[coluna], bins=20, right=True)
        df_proporcoes_corrigido[nome_coluna] = df_proporcoes_corrigido[nome_coluna].astype(str)

        df_proporcoes_agrupado = df_proporcoes_corrigido.groupby(nome_coluna)['saiu_banco'].value_counts(normalize=True).unstack()
        df_proporcoes_agrupado = df_proporcoes_agrupado.fillna(0)
        df_proporcoes_agrupado = df_proporcoes_agrupado * 100

        # Formata os valores como porcentagem com 2 casas decimais
        df_proporcoes_agrupado = df_proporcoes_agrupado.map(lambda x: f'{x:.2f}%')

        print(df_proporcoes_agrupado)

    else:
        df_proporcoes_agrupado = dataframe.groupby(coluna)['saiu_banco'].value_counts(normalize=True).unstack()
        df_proporcoes_agrupado = df_proporcoes_agrupado * 100

        # Formata os valores como porcentagem com 2 casas decimais
        df_proporcoes_agrupado = df_proporcoes_agrupado.map(lambda x: f'{x:.2f}%')

        print(df_proporcoes_agrupado)

    print("*-"*50)
    print()

# %%
df.columns.tolist()
# Out:
# ['id_cliente',
#  'pontuacao_credito',
#  'pais',
#  'genero',
#  'idade',
#  'tempo_relacionamento',
#  'saldo',
#  'numero_produtos',
#  'possui_cartao_credito',
#  'membro_ativo',
#  'salario_estimado',
#  'saiu_banco',
#  'faixa_etaria',
#  'outlier_pontuacao_credito',
#  'outlier_idade',
#  'outlier_tempo_relacionamento',
#  'outlier_saldo',
#  'outlier_numero_produtos',
#  'outlier_salario_estimado',
#  'outlier_faixa_etaria_pontuacao_credito',
#  'outlier_faixa_etaria_tempo_relacionamento',
#  'outlier_faixa_etaria_saldo',
#  'outlier_faixa_etaria_numero_produtos',
#  'outlier_faixa_etaria_salario_estimado',
#  'outlier_pais_pontuacao_credito',
#  'outlier_pais_tempo_relacionamento',
#  'outlier_pais_saldo',
#  'outlier_pais_numero_produtos',
#  'outlier_pais_salario_estimado']

# %%
colunas_graficos = [
 'pontuacao_credito',
 'pais',
 'genero',
 'idade',
 'tempo_relacionamento',
 'saldo',
 'numero_produtos',
 'possui_cartao_credito',
 'membro_ativo',
 'salario_estimado',
 'faixa_etaria',
 'outlier_pontuacao_credito',
 'outlier_idade',
 'outlier_numero_produtos',
 'outlier_faixa_etaria_pontuacao_credito',
 'outlier_faixa_etaria_numero_produtos',
 'outlier_pais_pontuacao_credito',
 'outlier_pais_tempo_relacionamento',
 'outlier_pais_saldo',
 'outlier_pais_numero_produtos',
 'outlier_pais_salario_estimado']

# %%
for coluna in colunas_graficos:
    fazer_graficos_histogramas(coluna, dataframe=df)
# Out:
# Para a coluna pontuacao_credito:
#
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: pontuacao_credito, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                          0        1
# pontuacao_credito_intervalada
# (349.5, 375.0]                  0.00%  100.00%
# (375.0, 400.0]                  0.00%  100.00%
# (400.0, 425.0]                 72.55%   27.45%
# (425.0, 450.0]                 76.47%   23.53%
# (450.0, 475.0]                 81.55%   18.45%
# (475.0, 500.0]                 79.02%   20.98%
# (500.0, 525.0]                 79.63%   20.37%
# (525.0, 550.0]                 76.59%   23.41%
# (550.0, 575.0]                 79.55%   20.45%
# (575.0, 600.0]                 79.37%   20.63%
# (600.0, 625.0]                 78.48%   21.52%
# (625.0, 650.0]                 79.57%   20.43%
# (650.0, 675.0]                 80.70%   19.30%
# (675.0, 700.0]                 82.21%   17.79%
# (700.0, 725.0]                 81.44%   18.56%
# (725.0, 750.0]                 77.83%   22.17%
# (750.0, 775.0]                 80.61%   19.39%
# (775.0, 800.0]                 80.30%   19.70%
# (800.0, 825.0]                 80.72%   19.28%
# (825.0, 850.0]                 80.05%   19.95%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna pais:
#
# pais
# França      0.5014
# Alemanha    0.2509
# Espanha     0.2477
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco       0       1
# pais
# Alemanha    67.56%  32.44%
# Espanha     83.33%  16.67%
# França      83.85%  16.15%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna genero:
#
# genero
# Masculino    0.5457
# Feminino     0.4543
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco       0       1
# genero
# Feminino    74.93%  25.07%
# Masculino   83.54%  16.46%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna idade:
#
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: idade, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco               0       1
# idade_intervalada
# (17.926, 21.7]      94.37%   5.63%
# (21.7, 25.4]        91.90%   8.10%
# (25.4, 29.1]        92.43%   7.57%
# (29.1, 32.8]        92.25%   7.75%
# (32.8, 36.5]        89.72%  10.28%
# (36.5, 40.2]        84.20%  15.80%
# (40.2, 43.9]        76.22%  23.78%
# (43.9, 47.6]        63.02%  36.98%
# (47.6, 51.3]        48.59%  51.41%
# (51.3, 55.0]        40.64%  59.36%
# (55.0, 58.7]        44.81%  55.19%
# (58.7, 62.4]        54.59%  45.41%
# (62.4, 66.1]        65.38%  34.62%
# (66.1, 69.8]        83.33%  16.67%
# (69.8, 73.5]        83.54%  16.46%
# (73.5, 77.2]        97.92%   2.08%
# (77.2, 80.9]       100.00%   0.00%
# (80.9, 84.6]        87.50%  12.50%
# (84.6, 88.3]       100.00%   0.00%
# (88.3, 92.0]       100.00%   0.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna tempo_relacionamento:
#
# count    10000.000000
# mean         5.012800
# std          2.892174
# min          0.000000
# 25%          3.000000
# 50%          5.000000
# 75%          7.000000
# max         10.000000
# Name: tempo_relacionamento, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                 0       1
# tempo_relacionamento
# 0                     77.00%  23.00%
# 1                     77.58%  22.42%
# 2                     80.82%  19.18%
# 3                     78.89%  21.11%
# 4                     79.47%  20.53%
# 5                     79.35%  20.65%
# 6                     79.73%  20.27%
# 7                     82.78%  17.22%
# 8                     80.78%  19.22%
# 9                     78.35%  21.65%
# 10                    79.39%  20.61%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna saldo:
#
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# max      250898.090000
# Name: saldo, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                     0        1
# saldo_intervalada
# (-250.898, 12544.904]     86.13%   13.87%
# (100359.236, 112904.141]  73.62%   26.38%
# (112904.141, 125449.045]  72.69%   27.31%
# (12544.904, 25089.809]    50.00%   50.00%
# (125449.045, 137993.95]   73.83%   26.17%
# (137993.95, 150538.854]   77.75%   22.25%
# (150538.854, 163083.758]  79.56%   20.44%
# (163083.758, 175628.663]  77.06%   22.94%
# (175628.663, 188173.568]  77.94%   22.06%
# (188173.568, 200718.472]  74.00%   26.00%
# (200718.472, 213263.376]  42.31%   57.69%
# (213263.376, 225808.281]  50.00%   50.00%
# (238353.186, 250898.09]    0.00%  100.00%
# (25089.809, 37634.714]    66.67%   33.33%
# (37634.714, 50179.618]    68.52%   31.48%
# (50179.618, 62724.523]    79.34%   20.66%
# (62724.523, 75269.427]    76.99%   23.01%
# (75269.427, 87814.332]    84.14%   15.86%
# (87814.332, 100359.236]   78.58%   21.42%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna numero_produtos:
#
# numero_produtos
# 1    0.5084
# 2    0.4590
# 3    0.0266
# 4    0.0060
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco            0        1
# numero_produtos
# 1                72.29%   27.71%
# 2                92.42%    7.58%
# 3                17.29%   82.71%
# 4                  nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna possui_cartao_credito:
#
# possui_cartao_credito
# 1    0.7055
# 0    0.2945
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                  0       1
# possui_cartao_credito
# 0                      79.19%  20.81%
# 1                      79.82%  20.18%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna membro_ativo:
#
# membro_ativo
# 1    0.5151
# 0    0.4849
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco         0       1
# membro_ativo
# 0             73.15%  26.85%
# 1             85.73%  14.27%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna salario_estimado:
#
# count     10000.000000
# mean     100090.239881
# std       57510.492818
# min          11.580000
# 25%       51002.110000
# 50%      100193.915000
# 75%      149388.247500
# max      199992.480000
# Name: salario_estimado, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                         0       1
# salario_estimado_intervalada
# (-188.401, 10010.625]         80.16%  19.84%
# (100002.03, 110001.075]       80.41%  19.59%
# (10010.625, 20009.67]         79.71%  20.29%
# (110001.075, 120000.12]       78.41%  21.59%
# (120000.12, 129999.165]       81.39%  18.61%
# (129999.165, 139998.21]       79.68%  20.32%
# (139998.21, 149997.255]       78.89%  21.11%
# (149997.255, 159996.3]        79.18%  20.82%
# (159996.3, 169995.345]        78.66%  21.34%
# (169995.345, 179994.39]       76.84%  23.16%
# (179994.39, 189993.435]       78.74%  21.26%
# (189993.435, 199992.48]       79.41%  20.59%
# (20009.67, 30008.715]         78.82%  21.18%
# (30008.715, 40007.76]         80.71%  19.29%
# (40007.76, 50006.805]         80.92%  19.08%
# (50006.805, 60005.85]         81.10%  18.90%
# (60005.85, 70004.895]         77.51%  22.49%
# (70004.895, 80003.94]         81.15%  18.85%
# (80003.94, 90002.985]         80.59%  19.41%
# (90002.985, 100002.03]        80.28%  19.72%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna faixa_etaria:
#
# count        10000
# unique          15
# top       [33, 38)
# freq          2297
# Name: faixa_etaria, dtype: object
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco          0       1
# faixa_etaria
# [18, 23)       91.15%   8.85%
# [23, 28)       93.32%   6.68%
# [28, 33)       92.09%   7.91%
# [33, 38)       89.16%  10.84%
# [38, 43)       81.67%  18.33%
# [43, 48)       64.86%  35.14%
# [48, 53)       46.87%  53.13%
# [53, 58)       41.04%  58.96%
# [58, 63)       55.07%  44.93%
# [63, 68)       70.06%  29.94%
# [68, 73)       81.31%  18.69%
# [73, 78)       96.72%   3.28%
# [78, 83)      100.00%    nan%
# [83, 88)       75.00%  25.00%
# [88, 93)      100.00%    nan%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pontuacao_credito:
#
# outlier_pontuacao_credito
# 0    0.9986
# 1    0.0014
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                      0        1
# outlier_pontuacao_credito
# 0                          79.74%   20.26%
# 1                            nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_idade:
#
# outlier_idade
# 0    0.9589
# 1    0.0411
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco          0       1
# outlier_idade
# 0              79.74%  20.26%
# 1              77.13%  22.87%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_numero_produtos:
#
# outlier_numero_produtos
# 0    0.994
# 1    0.006
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                    0        1
# outlier_numero_produtos
# 0                        80.11%   19.89%
# 1                          nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_faixa_etaria_pontuacao_credito:
#
# outlier_faixa_etaria_pontuacao_credito
# 0    0.9987
# 1    0.0013
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                                   0        1
# outlier_faixa_etaria_pontuacao_credito
# 0                                       79.73%   20.27%
# 1                                         nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_faixa_etaria_numero_produtos:
#
# outlier_faixa_etaria_numero_produtos
# 0    0.9939
# 1    0.0061
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                                 0       1
# outlier_faixa_etaria_numero_produtos
# 0                                     80.11%  19.89%
# 1                                      1.64%  98.36%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_pontuacao_credito:
#
# outlier_pais_pontuacao_credito
# 0    0.9983
# 1    0.0017
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                           0        1
# outlier_pais_pontuacao_credito
# 0                               79.77%   20.23%
# 1                                 nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_tempo_relacionamento:
#
# outlier_pais_tempo_relacionamento
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                              0       1
# outlier_pais_tempo_relacionamento
# 0                                  79.63%  20.37%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_saldo:
#
# outlier_pais_saldo
# 0    0.9967
# 1    0.0033
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                0       1
# outlier_pais_saldo
# 0                    79.56%  20.44%
# 1                   100.00%    nan%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_numero_produtos:
#
# outlier_pais_numero_produtos
# 0    0.994
# 1    0.006
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                         0        1
# outlier_pais_numero_produtos
# 0                             80.11%   19.89%
# 1                               nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_salario_estimado:
#
# outlier_pais_salario_estimado
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                          0       1
# outlier_pais_salario_estimado
# 0                              79.63%  20.37%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %%
print("Gráficos somente Espanha")

for coluna in colunas_graficos:
    fazer_graficos_histogramas(coluna, dataframe=df_espanha)
# Out:
# Gráficos somente Espanha
#
# Para a coluna pontuacao_credito:
#
# count    2477.000000
# mean      651.333872
# std        94.365051
# min       350.000000
# 25%       587.000000
# 50%       651.000000
# 75%       715.000000
# max       850.000000
# Name: pontuacao_credito, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                          0        1
# pontuacao_credito_intervalada
# (349.5, 375.0]                  0.00%  100.00%
# (375.0, 400.0]                  0.00%  100.00%
# (400.0, 425.0]                 75.00%   25.00%
# (425.0, 450.0]                 78.26%   21.74%
# (450.0, 475.0]                 91.67%    8.33%
# (475.0, 500.0]                 86.67%   13.33%
# (500.0, 525.0]                 81.11%   18.89%
# (525.0, 550.0]                 84.06%   15.94%
# (550.0, 575.0]                 83.64%   16.36%
# (575.0, 600.0]                 82.41%   17.59%
# (600.0, 625.0]                 83.40%   16.60%
# (625.0, 650.0]                 82.94%   17.06%
# (650.0, 675.0]                 82.68%   17.32%
# (675.0, 700.0]                 86.80%   13.20%
# (700.0, 725.0]                 83.02%   16.98%
# (725.0, 750.0]                 80.57%   19.43%
# (750.0, 775.0]                 84.30%   15.70%
# (775.0, 800.0]                 87.13%   12.87%
# (800.0, 825.0]                 82.69%   17.31%
# (825.0, 850.0]                 83.17%   16.83%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna pais:
#
# pais
# Espanha    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco       0       1
# pais
# Espanha     83.33%  16.67%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna genero:
#
# genero
# Masculino    0.560355
# Feminino     0.439645
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco       0       1
# genero
# Feminino    78.79%  21.21%
# Masculino   86.89%  13.11%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna idade:
#
# count    2477.000000
# mean       38.890997
# std        10.446119
# min        18.000000
# 25%        32.000000
# 50%        37.000000
# 75%        44.000000
# max        88.000000
# Name: idade, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco               0       1
# idade_intervalada
# (17.93, 21.5]       97.30%   2.70%
# (21.5, 25.0]        89.60%  10.40%
# (25.0, 28.5]        91.98%   8.02%
# (28.5, 32.0]        91.40%   8.60%
# (32.0, 35.5]        91.28%   8.72%
# (35.5, 39.0]        90.31%   9.69%
# (39.0, 42.5]        83.40%  16.60%
# (42.5, 46.0]        73.95%  26.05%
# (46.0, 49.5]        60.91%  39.09%
# (49.5, 53.0]        50.53%  49.47%
# (53.0, 56.5]        44.62%  55.38%
# (56.5, 60.0]        72.88%  27.12%
# (60.0, 63.5]        65.85%  34.15%
# (63.5, 67.0]        83.33%  16.67%
# (67.0, 70.5]        84.62%  15.38%
# (70.5, 74.0]        82.35%  17.65%
# (74.0, 77.5]       100.00%   0.00%
# (77.5, 81.0]       100.00%   0.00%
# (84.5, 88.0]       100.00%   0.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna tempo_relacionamento:
#
# count    2477.000000
# mean        5.032297
# std         2.856660
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000
# Name: tempo_relacionamento, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                 0       1
# tempo_relacionamento
# 0                     76.70%  23.30%
# 1                     81.82%  18.18%
# 2                     81.05%  18.95%
# 3                     82.10%  17.90%
# 4                     82.86%  17.14%
# 5                     83.96%  16.04%
# 6                     81.86%  18.14%
# 7                     84.06%  15.94%
# 8                     86.15%  13.85%
# 9                     84.83%  15.17%
# 10                    90.76%   9.24%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna saldo:
#
# count      2477.000000
# mean      61818.147763
# std       64235.555208
# min           0.000000
# 25%           0.000000
# 50%       61710.440000
# 75%      121056.630000
# max      250898.090000
# Name: saldo, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                      0        1
# saldo_intervalada
# (-250.898, 12544.904]      86.33%   13.67%
# (100359.236, 112904.141]   85.96%   14.04%
# (112904.141, 125449.045]   86.47%   13.53%
# (12544.904, 25089.809]    100.00%    0.00%
# (125449.045, 137993.95]    82.61%   17.39%
# (137993.95, 150538.854]    85.82%   14.18%
# (150538.854, 163083.758]   80.43%   19.57%
# (163083.758, 175628.663]   77.46%   22.54%
# (175628.663, 188173.568]   65.62%   34.38%
# (188173.568, 200718.472]   66.67%   33.33%
# (200718.472, 213263.376]   14.29%   85.71%
# (213263.376, 225808.281]   33.33%   66.67%
# (238353.186, 250898.09]     0.00%  100.00%
# (25089.809, 37634.714]     40.00%   60.00%
# (37634.714, 50179.618]     75.00%   25.00%
# (50179.618, 62724.523]     64.29%   35.71%
# (62724.523, 75269.427]     58.82%   41.18%
# (75269.427, 87814.332]     80.87%   19.13%
# (87814.332, 100359.236]    80.41%   19.59%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna numero_produtos:
#
# numero_produtos
# 1    0.492935
# 2    0.477594
# 3    0.026645
# 4    0.002826
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco            0        1
# numero_produtos
# 1                78.13%   21.87%
# 2                92.65%    7.35%
# 3                21.21%   78.79%
# 4                  nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna possui_cartao_credito:
#
# possui_cartao_credito
# 1    0.694792
# 0    0.305208
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                  0       1
# possui_cartao_credito
# 0                      82.14%  17.86%
# 1                      83.85%  16.15%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna membro_ativo:
#
# membro_ativo
# 1    0.529673
# 0    0.470327
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco         0       1
# membro_ativo
# 0             76.65%  23.35%
# 1             89.25%  10.75%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna salario_estimado:
#
# count      2477.000000
# mean      99440.572281
# std       57103.678091
# min         417.410000
# 25%       50267.690000
# 50%       99984.860000
# 75%      147278.430000
# max      199992.480000
# Name: salario_estimado, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                         0       1
# salario_estimado_intervalada
# (100204.945, 110183.699]      83.20%  16.80%
# (10396.164, 20374.917]        85.52%  14.48%
# (110183.699, 120162.452]      83.69%  16.31%
# (120162.452, 130141.206]      84.30%  15.70%
# (130141.206, 140119.959]      83.85%  16.15%
# (140119.959, 150098.713]      80.31%  19.69%
# (150098.713, 160077.466]      77.78%  22.22%
# (160077.466, 170056.22]       80.37%  19.63%
# (170056.22, 180034.973]       77.31%  22.69%
# (180034.973, 190013.727]      84.96%  15.04%
# (190013.727, 199992.48]       85.34%  14.66%
# (20374.917, 30353.671]        84.68%  15.32%
# (217.835, 10396.164]          84.25%  15.75%
# (30353.671, 40332.424]        83.33%  16.67%
# (40332.424, 50311.178]        85.27%  14.73%
# (50311.178, 60289.931]        88.33%  11.67%
# (60289.931, 70268.684]        82.30%  17.70%
# (70268.684, 80247.438]        85.48%  14.52%
# (80247.438, 90226.192]        81.48%  18.52%
# (90226.192, 100204.945]       84.73%  15.27%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna faixa_etaria:
#
# count         2477
# unique          14
# top       [33, 38)
# freq           578
# Name: faixa_etaria, dtype: object
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco          0       1
# faixa_etaria
# [18, 23)       90.77%   9.23%
# [23, 28)       92.63%   7.37%
# [28, 33)       91.15%   8.85%
# [33, 38)       91.87%   8.13%
# [38, 43)       85.66%  14.34%
# [43, 48)       71.57%  28.43%
# [48, 53)       56.76%  43.24%
# [53, 58)       50.93%  49.07%
# [58, 63)       74.19%  25.81%
# [63, 68)       76.00%  24.00%
# [68, 73)       80.00%  20.00%
# [73, 78)      100.00%    nan%
# [78, 83)      100.00%    nan%
# [88, 93)      100.00%    nan%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pontuacao_credito:
#
# outlier_pontuacao_credito
# 0    0.998385
# 1    0.001615
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                      0        1
# outlier_pontuacao_credito
# 0                          83.46%   16.54%
# 1                            nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_idade:
#
# outlier_idade
# 0    0.956803
# 1    0.043197
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco          0       1
# outlier_idade
# 0              83.46%  16.54%
# 1              80.37%  19.63%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_numero_produtos:
#
# outlier_numero_produtos
# 0    0.997174
# 1    0.002826
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                    0        1
# outlier_numero_produtos
# 0                        83.56%   16.44%
# 1                          nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_faixa_etaria_pontuacao_credito:
#
# outlier_faixa_etaria_pontuacao_credito
# 0    0.998385
# 1    0.001615
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                                   0        1
# outlier_faixa_etaria_pontuacao_credito
# 0                                       83.46%   16.54%
# 1                                         nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_faixa_etaria_numero_produtos:
#
# outlier_faixa_etaria_numero_produtos
# 0    0.997174
# 1    0.002826
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                                 0        1
# outlier_faixa_etaria_numero_produtos
# 0                                     83.56%   16.44%
# 1                                       nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_pontuacao_credito:
#
# outlier_pais_pontuacao_credito
# 0    0.997174
# 1    0.002826
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                           0        1
# outlier_pais_pontuacao_credito
# 0                               83.56%   16.44%
# 1                                 nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_tempo_relacionamento:
#
# outlier_pais_tempo_relacionamento
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                              0       1
# outlier_pais_tempo_relacionamento
# 0                                  83.33%  16.67%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_saldo:
#
# outlier_pais_saldo
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco               0       1
# outlier_pais_saldo
# 0                   83.33%  16.67%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_numero_produtos:
#
# outlier_pais_numero_produtos
# 0    0.997174
# 1    0.002826
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                         0        1
# outlier_pais_numero_produtos
# 0                             83.56%   16.44%
# 1                               nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_salario_estimado:
#
# outlier_pais_salario_estimado
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                          0       1
# outlier_pais_salario_estimado
# 0                              83.33%  16.67%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %%
print("Gráficos somente Alemanha")

for coluna in colunas_graficos:
    fazer_graficos_histogramas(coluna, dataframe=df_alemanha)
# Out:
# Gráficos somente Alemanha
#
# Para a coluna pontuacao_credito:
#
# count    2509.000000
# mean      651.453567
# std        98.168937
# min       350.000000
# 25%       584.000000
# 50%       651.000000
# 75%       722.000000
# max       850.000000
# Name: pontuacao_credito, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                          0        1
# pontuacao_credito_intervalada
# (349.5, 375.0]                  0.00%  100.00%
# (375.0, 400.0]                  0.00%  100.00%
# (400.0, 425.0]                 63.64%   36.36%
# (425.0, 450.0]                 55.17%   44.83%
# (450.0, 475.0]                 77.08%   22.92%
# (475.0, 500.0]                 66.25%   33.75%
# (500.0, 525.0]                 66.02%   33.98%
# (525.0, 550.0]                 62.96%   37.04%
# (550.0, 575.0]                 64.71%   35.29%
# (575.0, 600.0]                 66.82%   33.18%
# (600.0, 625.0]                 67.45%   32.55%
# (625.0, 650.0]                 68.52%   31.48%
# (650.0, 675.0]                 70.39%   29.61%
# (675.0, 700.0]                 72.65%   27.35%
# (700.0, 725.0]                 69.95%   30.05%
# (725.0, 750.0]                 62.42%   37.58%
# (750.0, 775.0]                 66.46%   33.54%
# (775.0, 800.0]                 65.66%   34.34%
# (800.0, 825.0]                 71.23%   28.77%
# (825.0, 850.0]                 69.61%   30.39%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna pais:
#
# pais
# Alemanha    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco       0       1
# pais
# Alemanha    67.56%  32.44%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna genero:
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# genero
# Masculino    0.524512
# Feminino     0.475488
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco       0       1
# genero
# Feminino    62.45%  37.55%
# Masculino   72.19%  27.81%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna idade:
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# count    2509.000000
# mean       39.771622
# std        10.519143
# min        18.000000
# 25%        32.000000
# 50%        38.000000
# 75%        45.000000
# max        84.000000
# Name: idade, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco               0       1
# idade_intervalada
# (17.934, 21.3]      83.87%  16.13%
# (21.3, 24.6]        84.62%  15.38%
# (24.6, 27.9]        93.28%   6.72%
# (27.9, 31.2]        86.45%  13.55%
# (31.2, 34.5]        85.03%  14.97%
# (34.5, 37.8]        78.93%  21.07%
# (37.8, 41.1]        71.43%  28.57%
# (41.1, 44.4]        61.89%  38.11%
# (44.4, 47.7]        39.23%  60.77%
# (47.7, 51.0]        32.46%  67.54%
# (51.0, 54.3]        32.50%  67.50%
# (54.3, 57.6]        21.88%  78.12%
# (57.6, 60.9]        37.29%  62.71%
# (60.9, 64.2]        46.51%  53.49%
# (64.2, 67.5]        38.89%  61.11%
# (67.5, 70.8]        68.42%  31.58%
# (70.8, 74.1]        80.00%  20.00%
# (74.1, 77.4]       100.00%   0.00%
# (77.4, 80.7]       100.00%   0.00%
# (80.7, 84.0]       100.00%   0.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna tempo_relacionamento:
#
# count    2509.000000
# mean        5.009964
# std         2.935154
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000
# Name: tempo_relacionamento, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                 0       1
# tempo_relacionamento
# 0                     65.71%  34.29%
# 1                     60.23%  39.77%
# 2                     76.73%  23.27%
# 3                     67.82%  32.18%
# 4                     67.24%  32.76%
# 5                     65.25%  34.75%
# 6                     66.52%  33.48%
# 7                     72.89%  27.11%
# 8                     67.05%  32.95%
# 9                     65.43%  34.57%
# 10                    67.19%  32.81%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna saldo:
#
# count      2509.000000
# mean     119730.116134
# std       27022.006157
# min       27288.430000
# 25%      102800.720000
# 50%      119703.100000
# 75%      137560.380000
# max      214346.960000
# Name: saldo, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                      0       1
# saldo_intervalada
# (102111.842, 111464.768]   58.52%  41.48%
# (111464.768, 120817.695]   53.53%  46.47%
# (120817.695, 130170.622]   62.09%  37.91%
# (130170.622, 139523.548]   64.21%  35.79%
# (139523.548, 148876.474]   68.83%  31.17%
# (148876.474, 158229.401]   73.08%  26.92%
# (158229.401, 167582.327]   77.63%  22.37%
# (167582.327, 176935.254]   86.79%  13.21%
# (176935.254, 186288.18]    96.88%   3.12%
# (186288.18, 195641.107]   100.00%   0.00%
# (195641.107, 204994.034]  100.00%   0.00%
# (204994.034, 214346.96]   100.00%   0.00%
# (27101.371, 36641.356]    100.00%   0.00%
# (36641.356, 45994.283]    100.00%   0.00%
# (45994.283, 55347.21]     100.00%   0.00%
# (55347.21, 64700.136]      94.87%   5.13%
# (64700.136, 74053.062]     92.00%   8.00%
# (74053.062, 83405.989]     80.95%  19.05%
# (83405.989, 92758.916]     81.62%  18.38%
# (92758.916, 102111.842]    66.80%  33.20%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna numero_produtos:
#
# numero_produtos
# 1    0.537664
# 2    0.414508
# 3    0.038262
# 4    0.009566
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco            0        1
# numero_produtos
# 1                57.15%   42.85%
# 2                87.88%   12.12%
# 3                10.42%   89.58%
# 4                  nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna possui_cartao_credito:
#
# possui_cartao_credito
# 1    0.71383
# 0    0.28617
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                  0       1
# possui_cartao_credito
# 0                      66.99%  33.01%
# 1                      67.78%  32.22%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna membro_ativo:
#
# membro_ativo
# 0    0.502591
# 1    0.497409
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco         0       1
# membro_ativo
# 0             58.92%  41.08%
# 1             76.28%  23.72%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna salario_estimado:
#
# count      2509.000000
# mean     101113.435102
# std       58263.011501
# min          11.580000
# 25%       51016.020000
# 50%      102397.220000
# 75%      151083.800000
# max      199970.740000
# Name: salario_estimado, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                         0       1
# salario_estimado_intervalada
# (-188.379, 10009.538]         60.63%  39.37%
# (10009.538, 20007.496]        63.64%  36.36%
# (109989.118, 119987.076]      64.66%  35.34%
# (119987.076, 129985.034]      68.00%  32.00%
# (129985.034, 139982.992]      70.87%  29.13%
# (139982.992, 149980.95]       66.15%  33.85%
# (149980.95, 159978.908]       71.88%  28.12%
# (159978.908, 169976.866]      66.94%  33.06%
# (169976.866, 179974.824]      71.62%  28.38%
# (179974.824, 189972.782]      64.84%  35.16%
# (189972.782, 199970.74]       70.92%  29.08%
# (20007.496, 30005.454]        67.44%  32.56%
# (30005.454, 40003.412]        69.75%  30.25%
# (40003.412, 50001.37]         60.31%  39.69%
# (50001.37, 59999.328]         73.72%  26.28%
# (59999.328, 69997.286]        61.34%  38.66%
# (69997.286, 79995.244]        70.99%  29.01%
# (79995.244, 89993.202]        63.72%  36.28%
# (89993.202, 99991.16]         69.83%  30.17%
# (99991.16, 109989.118]        71.83%  28.17%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna faixa_etaria:
#
# count         2509
# unique          14
# top       [33, 38)
# freq           531
# Name: faixa_etaria, dtype: object
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco          0       1
# faixa_etaria
# [18, 23)       85.71%  14.29%
# [23, 28)       90.43%   9.57%
# [28, 33)       86.83%  13.17%
# [33, 38)       80.60%  19.40%
# [38, 43)       71.46%  28.54%
# [43, 48)       47.18%  52.82%
# [48, 53)       33.33%  66.67%
# [53, 58)       24.78%  75.22%
# [58, 63)       40.91%  59.09%
# [63, 68)       40.62%  59.38%
# [68, 73)       68.97%  31.03%
# [73, 78)       94.74%   5.26%
# [78, 83)      100.00%    nan%
# [83, 88)      100.00%    nan%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pontuacao_credito:
#
# outlier_pontuacao_credito
# 0    0.998406
# 1    0.001594
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                      0        1
# outlier_pontuacao_credito
# 0                          67.66%   32.34%
# 1                            nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_idade:
#
# outlier_idade
# 0    0.960941
# 1    0.039059
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco          0       1
# outlier_idade
# 0              67.81%  32.19%
# 1              61.22%  38.78%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_numero_produtos:
#
# outlier_numero_produtos
# 0    0.990434
# 1    0.009566
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                    0        1
# outlier_numero_produtos
# 0                        68.21%   31.79%
# 1                          nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_faixa_etaria_pontuacao_credito:
#
# outlier_faixa_etaria_pontuacao_credito
# 0    0.998804
# 1    0.001196
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                                   0        1
# outlier_faixa_etaria_pontuacao_credito
# 0                                       67.64%   32.36%
# 1                                         nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_faixa_etaria_numero_produtos:
#
# outlier_faixa_etaria_numero_produtos
# 0    0.990434
# 1    0.009566
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                                 0        1
# outlier_faixa_etaria_numero_produtos
# 0                                     68.21%   31.79%
# 1                                       nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_pontuacao_credito:
#
# outlier_pais_pontuacao_credito
# 0    0.998406
# 1    0.001594
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                           0        1
# outlier_pais_pontuacao_credito
# 0                               67.66%   32.34%
# 1                                 nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_tempo_relacionamento:
#
# outlier_pais_tempo_relacionamento
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                              0       1
# outlier_pais_tempo_relacionamento
# 0                                  67.56%  32.44%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_saldo:
#
# outlier_pais_saldo
# 0    0.986847
# 1    0.013153
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                0       1
# outlier_pais_saldo
# 0                    67.12%  32.88%
# 1                   100.00%    nan%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_numero_produtos:
#
# outlier_pais_numero_produtos
# 0    0.990434
# 1    0.009566
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                         0        1
# outlier_pais_numero_produtos
# 0                             68.21%   31.79%
# 1                               nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_salario_estimado:
#
# outlier_pais_salario_estimado
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                          0       1
# outlier_pais_salario_estimado
# 0                              67.56%  32.44%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %%
print("Gráficos somente França")

for coluna in colunas_graficos:
    fazer_graficos_histogramas(coluna, dataframe=df_franca)
# Out:
# Gráficos somente França
#
# Para a coluna pontuacao_credito:
#
# count    5014.000000
# mean      649.668329
# std        97.016799
# min       350.000000
# 25%       582.000000
# 50%       653.000000
# 75%       717.000000
# max       850.000000
# Name: pontuacao_credito, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                          0        1
# pontuacao_credito_intervalada
# (349.5, 375.0]                  0.00%  100.00%
# (375.0, 400.0]                  0.00%  100.00%
# (400.0, 425.0]                 75.00%   25.00%
# (425.0, 450.0]                 85.07%   14.93%
# (450.0, 475.0]                 79.76%   20.24%
# (475.0, 500.0]                 82.88%   17.12%
# (500.0, 525.0]                 85.04%   14.96%
# (525.0, 550.0]                 79.50%   20.50%
# (550.0, 575.0]                 83.75%   16.25%
# (575.0, 600.0]                 84.79%   15.21%
# (600.0, 625.0]                 81.12%   18.88%
# (625.0, 650.0]                 84.25%   15.75%
# (650.0, 675.0]                 84.55%   15.45%
# (675.0, 700.0]                 84.16%   15.84%
# (700.0, 725.0]                 86.08%   13.92%
# (725.0, 750.0]                 84.04%   15.96%
# (750.0, 775.0]                 87.27%   12.73%
# (775.0, 800.0]                 84.18%   15.82%
# (800.0, 825.0]                 85.48%   14.52%
# (825.0, 850.0]                 83.94%   16.06%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna pais:
#
# pais
# França    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco       0       1
# pais
# França      83.85%  16.15%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna genero:
#
# genero
# Masculino    0.549063
# Feminino     0.450937
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco       0       1
# genero
# Feminino    79.66%  20.34%
# Masculino   87.29%  12.71%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna idade:
#
# count    5014.000000
# mean       38.511767
# std        10.469459
# min        18.000000
# 25%        31.000000
# 50%        37.000000
# 75%        43.000000
# max        92.000000
# Name: idade, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco               0       1
# idade_intervalada
# (17.926, 21.7]      97.30%   2.70%
# (21.7, 25.4]        93.97%   6.03%
# (25.4, 29.1]        94.82%   5.18%
# (29.1, 32.8]        94.60%   5.40%
# (32.8, 36.5]        92.16%   7.84%
# (36.5, 40.2]        87.18%  12.82%
# (40.2, 43.9]        79.87%  20.13%
# (43.9, 47.6]        70.56%  29.44%
# (47.6, 51.3]        54.98%  45.02%
# (51.3, 55.0]        44.30%  55.70%
# (55.0, 58.7]        48.19%  51.81%
# (58.7, 62.4]        54.24%  45.76%
# (62.4, 66.1]        73.53%  26.47%
# (66.1, 69.8]        91.67%   8.33%
# (69.8, 73.5]        88.64%  11.36%
# (73.5, 77.2]       100.00%   0.00%
# (77.2, 80.9]       100.00%   0.00%
# (80.9, 84.6]        80.00%  20.00%
# (84.6, 88.3]       100.00%   0.00%
# (88.3, 92.0]       100.00%   0.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna tempo_relacionamento:
#
# count    5014.000000
# mean        5.004587
# std         2.888475
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%         7.000000
# max        10.000000
# Name: tempo_relacionamento, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                 0       1
# tempo_relacionamento
# 0                     82.93%  17.07%
# 1                     84.31%  15.69%
# 2                     82.86%  17.14%
# 3                     83.10%  16.90%
# 4                     83.40%  16.60%
# 5                     84.33%  15.67%
# 6                     84.69%  15.31%
# 7                     86.23%  13.77%
# 8                     85.16%  14.84%
# 9                     82.54%  17.46%
# 10                    80.25%  19.75%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna saldo:
#
# count      5014.000000
# mean      62092.636516
# std       64133.565524
# min           0.000000
# 25%           0.000000
# 50%       62153.500000
# 75%      121444.877500
# max      238387.560000
# Name: saldo, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                     0        1
# saldo_intervalada
# (-238.388, 11919.378]     86.03%   13.97%
# (107274.402, 119193.78]   85.98%   14.02%
# (11919.378, 23838.756]    50.00%   50.00%
# (119193.78, 131113.158]   82.99%   17.01%
# (131113.158, 143032.536]  83.48%   16.52%
# (143032.536, 154951.914]  80.08%   19.92%
# (154951.914, 166871.292]  84.85%   15.15%
# (166871.292, 178790.67]   68.04%   31.96%
# (178790.67, 190710.048]   70.00%   30.00%
# (190710.048, 202629.426]  59.09%   40.91%
# (202629.426, 214548.804]  45.45%   54.55%
# (226468.182, 238387.56]    0.00%  100.00%
# (23838.756, 35758.134]    25.00%   75.00%
# (35758.134, 47677.512]    51.72%   48.28%
# (47677.512, 59596.89]     75.00%   25.00%
# (59596.89, 71516.268]     78.26%   21.74%
# (71516.268, 83435.646]    82.61%   17.39%
# (83435.646, 95355.024]    84.55%   15.45%
# (95355.024, 107274.402]   85.55%   14.45%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna numero_produtos:
#
# numero_produtos
# 1    0.501396
# 2    0.472078
# 3    0.020742
# 4    0.005784
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco            0        1
# numero_produtos
# 1                77.57%   22.43%
# 2                94.30%    5.70%
# 3                21.15%   78.85%
# 4                  nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna possui_cartao_credito:
#
# possui_cartao_credito
# 1    0.706621
# 0    0.293379
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                  0       1
# possui_cartao_credito
# 0                      83.62%  16.38%
# 1                      83.94%  16.06%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna membro_ativo:
#
# membro_ativo
# 1    0.516753
# 0    0.483247
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco         0       1
# membro_ativo
# 0             78.87%  21.13%
# 1             88.50%  11.50%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna salario_estimado:
#
# count      5014.000000
# mean      99899.180814
# std       57336.289016
# min          90.070000
# 25%       51399.190000
# 50%       99132.310000
# 75%      149295.360000
# max      199929.170000
# Name: salario_estimado, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                         0       1
# salario_estimado_intervalada
# (-109.769, 10082.025]         87.69%  12.31%
# (100009.62, 110001.575]       83.52%  16.48%
# (10082.025, 20073.98]         83.63%  16.37%
# (110001.575, 119993.53]       82.63%  17.37%
# (119993.53, 129985.485]       85.66%  14.34%
# (129985.485, 139977.44]       82.99%  17.01%
# (139977.44, 149969.395]       84.15%  15.85%
# (149969.395, 159961.35]       83.12%  16.88%
# (159961.35, 169953.305]       83.81%  16.19%
# (169953.305, 179945.26]       79.39%  20.61%
# (179945.26, 189937.215]       83.26%  16.74%
# (189937.215, 199929.17]       81.57%  18.43%
# (20073.98, 30065.935]         82.66%  17.34%
# (30065.935, 40057.89]         84.80%  15.20%
# (40057.89, 50049.845]         88.70%  11.30%
# (50049.845, 60041.8]          81.93%  18.07%
# (60041.8, 70033.755]          83.15%  16.85%
# (70033.755, 80025.71]         83.96%  16.04%
# (80025.71, 90017.665]         87.64%  12.36%
# (90017.665, 100009.62]        82.59%  17.41%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna faixa_etaria:
#
# count         5014
# unique          15
# top       [33, 38)
# freq          1188
# Name: faixa_etaria, dtype: object
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco          0       1
# faixa_etaria
# [18, 23)       93.28%   6.72%
# [23, 28)       94.95%   5.05%
# [28, 33)       94.80%   5.20%
# [33, 38)       91.67%   8.33%
# [38, 43)       84.64%  15.36%
# [43, 48)       72.08%  27.92%
# [48, 53)       52.00%  48.00%
# [53, 58)       45.73%  54.27%
# [58, 63)       55.48%  44.52%
# [63, 68)       77.65%  22.35%
# [68, 73)       88.68%  11.32%
# [73, 78)       96.55%   3.45%
# [78, 83)      100.00%    nan%
# [83, 88)       50.00%  50.00%
# [88, 93)      100.00%    nan%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pontuacao_credito:
#
# outlier_pontuacao_credito
# 0    0.998803
# 1    0.001197
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                      0        1
# outlier_pontuacao_credito
# 0                          83.95%   16.05%
# 1                            nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_idade:
#
# outlier_idade
# 0    0.958915
# 1    0.041085
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco          0       1
# outlier_idade
# 0              83.88%  16.12%
# 1              83.01%  16.99%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_numero_produtos:
#
# outlier_numero_produtos
# 0    0.994216
# 1    0.005784
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                    0        1
# outlier_numero_produtos
# 0                        84.33%   15.67%
# 1                          nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_faixa_etaria_pontuacao_credito:
#
# outlier_faixa_etaria_pontuacao_credito
# 0    0.998803
# 1    0.001197
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                                   0        1
# outlier_faixa_etaria_pontuacao_credito
# 0                                       83.95%   16.05%
# 1                                         nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_faixa_etaria_numero_produtos:
#
# outlier_faixa_etaria_numero_produtos
# 0    0.994017
# 1    0.005983
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                                 0       1
# outlier_faixa_etaria_numero_produtos
# 0                                     84.33%  15.67%
# 1                                      3.33%  96.67%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_pontuacao_credito:
#
# outlier_pais_pontuacao_credito
# 0    0.998803
# 1    0.001197
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                           0        1
# outlier_pais_pontuacao_credito
# 0                               83.95%   16.05%
# 1                                 nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_tempo_relacionamento:
#
# outlier_pais_tempo_relacionamento
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                              0       1
# outlier_pais_tempo_relacionamento
# 0                                  83.85%  16.15%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_saldo:
#
# outlier_pais_saldo
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco               0       1
# outlier_pais_saldo
# 0                   83.85%  16.15%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_numero_produtos:
#
# outlier_pais_numero_produtos
# 0    0.994216
# 1    0.005784
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                         0        1
# outlier_pais_numero_produtos
# 0                             84.33%   15.67%
# 1                               nan%  100.00%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
#
# Para a coluna outlier_pais_salario_estimado:
#
# outlier_pais_salario_estimado
# 0    1.0
# Name: proportion, dtype: float64
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# saiu_banco                          0       1
# outlier_pais_salario_estimado
# 0                              83.85%  16.15%
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="7"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>7. INSIGHTS E CONCLUSÕES 📊</strong></p>
#
# - **Esta seção apresenta os principais insights e conclusões obtidos a partir da análise exploratória dos dados do Blue Bank. Os insights são derivados das respostas às perguntas de negócio formuladas anteriormente e são fundamentais para orientar as estratégias de retenção de clientes do banco.**
#
# - **Principais Insights:**
#     - 💡 **Insight 1:** Descrição do insight, incluindo quais dados foram analisados e quais resultados foram observados.
#     - 💡 **Insight 2:** Discussão sobre como um determinado atributo ou combinação de atributos afeta o churn dos clientes.
#     - 💡 **Insight 3:** Análise da influência de fatores demográficos ou comportamentais no comportamento de churn.
#     - 💡 **Outros insights relevantes derivados da análise.**
#
# - **Conclusões:**
#     - 💡 **Conclusão 1:** Sumário das implicações dos insights para as operações e estratégias do Blue Bank.
#     - 💡 **Conclusão 2:** Recomendações para ações específicas baseadas nos dados analisados.
#     - 💡 **Conclusão 3:** Sugestões para futuras análises ou áreas que requerem mais investigação detalhada.
#
# - **Impacto Potencial:**
#     - **Discutiremos o potencial impacto desses insights nas estratégias de retenção e crescimento do cliente, identificando oportunidades de melhoria e inovação.**

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="8"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>8. RECOMENDAÇÕES 📝</strong></p>
#
# - **Baseadas nos insights derivados da análise exploratória de dados, propomos as seguintes recomendações para o Blue Bank com o objetivo de melhorar a retenção de clientes e reduzir as taxas de churn:**
#
#     - 🎯 **Recomendação 1:** Implementar estratégias de engajamento direcionadas para grupos de clientes com alta probabilidade de churn identificados na análise, como jovens em faixas etárias específicas ou clientes com baixo número de produtos.
#     - 🌍 **Recomendação 2:** Desenvolver programas de fidelidade ou benefícios adicionais para clientes em regiões com maiores taxas de churn, como mostrado nos dados geográficos.
#     - 🔍 **Recomendação 3:** Oferecer serviços financeiros personalizados que atendam às necessidades específicas dos segmentos de clientes mais propensos a sair, com base na análise de dados sobre saldo, produtos e atividade.
#     - 📞 **Recomendação 4:** Aumentar a comunicação e o suporte ao cliente, especialmente para aqueles que demonstram sinais de inatividade ou descontentamento.
#     - 🔄 **Recomendação 5:** Utilizar análises preditivas para identificar sinais de churn precoce, permitindo intervenções proativas antes que o cliente decida sair.
#
# - **Essas recomendações são projetadas para serem implementadas de maneira faseada e avaliadas continuamente para eficácia, garantindo que o Blue Bank possa adaptar suas estratégias conforme necessário para maximizar a retenção de clientes.**

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="9"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:left; border-radius:10px 10px; margin-bottom: -25px; padding-left: 75px;"><strong>9. CONCLUSÃO 🏁</strong></p>
#
# - **Esta seção final resume os insights chave e as ações recomendadas baseadas na análise exploratória de dados realizada. Refletimos sobre o impacto potencial dessas ações e consideramos os passos futuros para a continuação da melhoria das estratégias de retenção de clientes do Blue Bank.**
#
# - **Pontos Principais:**
#     - Sumário dos insights mais impactantes obtidos da análise.
#     - Avaliação da resposta às perguntas de negócio inicialmente propostas.
#     - Discussão sobre a eficácia das recomendações implementadas e sugestões para ajustes.
#
# - **Futuras Direções:**
#     - Propostas para estudos adicionais baseados em lacunas identificadas durante a análise.
#     - Tecnologias ou metodologias emergentes que podem ser exploradas em futuras atualizações do projeto.
#
# - **Agradecimentos:**
#     - Expressão de gratidão a todos os colaboradores e mentores que apoiaram o projeto.
